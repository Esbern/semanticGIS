# %%
import geopandas as gpd
import duckdb

# %%
con = duckdb.connect()
con.execute("INSTALL spatial;")
con.execute("LOAD spatial;")
con.execute("INSTALL httpfs;")
con.execute("LOAD httpfs;")

# %%
europa_url = "https://raw.githubusercontent.com/Esbern/gis_demo_data/main/europa.geojson"
gdf = gpd.read_file(europa_url)

# %%
out = con.sql("select * from read_json('https://raw.githubusercontent.com/Esbern/gis_demo_data/main/europa.geojson');")

# %%
con.sql("CREATE TABLE tbl_node_1 AS SELECT * FROM ST_Read('https://raw.githubusercontent.com/Esbern/gis_demo_data/main/europa.geojson');");
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
con.sql("CREATE TABLE my_table AS SELECT * FROM ST_Read('https://raw.githubusercontent.com/Esbern/gis_demo_data/main/europa.geojson')")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
print(con.sql("DESCRIBE tbl_node_1;"))
# Out:
# ┌─────────────┬─────────────┬─────────┬─────────┬─────────┬─────────┐
# │ column_name │ column_type │  null   │   key   │ default │  extra  │
# │   varchar   │   varchar   │ varchar │ varchar │ varchar │ varchar │
# ├─────────────┼─────────────┼─────────┼─────────┼─────────┼─────────┤
# │ featurecla  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ scalerank   │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ LABELRANK   │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ SOVEREIGNT  │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ SOV_A3      │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ ADM0_DIF    │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ LEVEL       │ INTEGER     │ YES     │ NULL    │ NULL    │ NULL    │
# │ TYPE        │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# │ TLC         │ VARCHAR     │ YES     │ NULL    │ NULL    │ NULL    │
# ...

# %%
conn.execute("describe out")

# %%
df = zone_trips.to_df()
gdf['geometry'] = gdf['geometry'].to_wkt()

out = conn.sql("""
  SELECT
   *
  FROM gdf where SOVEREIGNT = 'Denamrk'
""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 gdf['geometry'] = gdf['geometry'].to_wkt()
#       3 out = conn.sql("""
#       4   SELECT
#       5    *
#       6   FROM gdf where SOVEREIGNT = 'Denamrk'
#       7 """)
#
# NameError: name 'gdf' is not defined

# %%
out['geometry'] = gpd.GeoSeries.from_wkt(out['geometry'])
gdf = gpd.GeoDataFrame(out)

# %%
out1 = duckdb.sql("SELECT * FROM out where SOVEREIGNT = 'Denmark' LIMIT 5")
out1
# Out:
# ┌─────────────────┬───────────┬───────────┬────────────┬─────────┬──────────┬───────┬────────────┬─────────┬───────────────┬─────────┬──────────┬───────────────┬─────────┬────────┬───────────────┬─────────┬──────────┬────────────┬────────────────┬─────────┬────────────────┬───────────┬────────────┬─────────┬──────────────────────┬───────────┬───────────────┬───────────┬──────────┬────────────────┬──────────┬───────────┬───────────┬───────────┬────────────┬───────────┬──────────┬──────────┬────────┬──────────┬──────────────────────┬──────────────────────┬─────────┬─────────┬───────────┬─────────┬───────────┬─────────┬───────────┬─────────┬─────────┬─────────┬──────────┬───────────┬──────────────────────┬──────────┬───────────┬──────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬────────────┬─────
# ...

# %%
gdf
# Out:
#          featurecla  scalerank  LABELRANK      SOVEREIGNT SOV_A3  ADM0_DIF  \
# 0   Admin-0 country          3          3  United Kingdom    GB1         1
# 1   Admin-0 country          1          5          Cyprus    CYP         0
# 2   Admin-0 country          0          4          Israel    IS1         1
# 3   Admin-0 country          0          5          Israel    IS1         1
# 4   Admin-0 country          0          5         Lebanon    LBN         0
# ..              ...        ...        ...             ...    ...       ...
# 64  Admin-0 country          5          6  United Kingdom    GB1         1
# 65  Admin-0 country          5          6  United Kingdom    GB1         1
# 66  Admin-0 country          6          6  United Kingdom    GB1         1
# 67  Admin-0 country          3          6         Finland    FI1         1
# 68  Admin-0 country          5          6         Denmark    DN1         1
#
# ...
